# %% [markdown]
# # Assignment on Python for Data Science

# %% [markdown]
# importing library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment.

# %% [markdown]
# # reading excel

# %%
iris=pd.read_excel('iris.xls')

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2.Display the columns in the dataset.

# %% [markdown]
# # display column

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3.Calculate the mean of each column of the dataset.

# %% [markdown]
# # calculate mean

# %%
iris.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %% [markdown]
# # check for null

# %%
iris.isnull().values.any()
# Out:
# False

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# # PairPlot

# %%
sns.pairplot(iris)

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='SL',y="SW",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='SL',y="PL",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='PL'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='SL',y="PW",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='PW'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='SW',y="PL",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='PL'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='SW',y="PW",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='SW', ylabel='PW'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='PL',y="PW",hue='Classification',data=iris)
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>
